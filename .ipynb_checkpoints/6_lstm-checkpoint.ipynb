# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
print(text[:1000])
# Out:
# Data size 100000000
#  anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
#     print (self._cursor)
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
#       print(self._text[self._cursor[b]:self._cursor[b]+10])
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
#     print (batches2string([batch]))
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293800 learning rate: 10.000000
# Minibatch perplexity: 26.95
# ================================================================================
# ipbrmte rssutschizhtboga   razfhz flnuxlilfromldunf l czesatn c pwiieaefibexvewv
# zde jhnsfd n gqemo tvm yvcrejnhqksitdqssueixrhvbrhztfaeikitcgziwobtfp  ce prahai
# os  bdmqnhkm g nruhdosc g dti ssvisal nc  adl hxaasvtrtpqirtdpqojjpmfb blkg i ht
# bimnymilgajhx  oo  u c geun zefeeqfgnioytnnrmnmxdgehbcbapmnsgxeidng x oedfnpoaen
# odkazhkbj gieootmglwwliwitft fs cwz kvokally opea  gopwfi tufiyduqs kpo ekkehlhk
# ================================================================================
# Validation set perplexity: 20.17
# Average loss at step 100: 2.596372 learning rate: 10.000000
# Minibatch perplexity: 10.65
# Validation set perplexity: 10.21
# Average loss at step 200: 2.254138 learning rate: 10.000000
# Minibatch perplexity: 8.64
# Validation set perplexity: 8.55
# Average loss at step 300: 2.103772 learning rate: 10.000000
# Minibatch perplexity: 7.42
# Validation set perplexity: 8.19
# Average loss at step 400: 2.001220 learning rate: 10.000000
# Minibatch perplexity: 7.53
# Validation set perplexity: 7.79
# Average loss at step 500: 1.934351 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 7.06
# Average loss at step 600: 1.904544 learning rate: 10.000000
# Minibatch perplexity: 6.05
# Validation set perplexity: 6.82
# Average loss at step 700: 1.854829 learning rate: 10.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 6.62
# Average loss at step 800: 1.815679 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 6.29
# Average loss at step 900: 1.825890 learning rate: 10.000000
# Minibatch perplexity: 6.94
# Validation set perplexity: 6.17
# Average loss at step 1000: 1.822169 learning rate: 10.000000
# Minibatch perplexity: 5.66
# ================================================================================
# an exer hunchist actatial anmination is ofrecial yert wither three create mich a
# cerl the greetery the gepa therlizity of ininitue spect irmary to tion e veripha
# ge forry murius and he posperies and necold in the one newre several carra raul
# mera hume sin hidwerally be and hiether ippessillation whob a can yet of mase th
# he lowensa farrsts tere fake two zero zero one two s a kulliby in referse in not
# ================================================================================
# Validation set perplexity: 6.10
# Average loss at step 1100: 1.774175 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 6.02
# Average loss at step 1200: 1.751235 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.74
# Average loss at step 1300: 1.733453 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 5.78
# Average loss at step 1400: 1.749362 learning rate: 10.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 5.55
# Average loss at step 1500: 1.738192 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 5.42
# Average loss at step 1600: 1.744274 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 5.44
# Average loss at step 1700: 1.710268 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.42
# Average loss at step 1800: 1.674042 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 5.28
# Average loss at step 1900: 1.644501 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 5.17
# Average loss at step 2000: 1.695487 learning rate: 10.000000
# Minibatch perplexity: 5.55
# ================================================================================
# mins of mussion list abf shons parts we su per france habuding giblicansuig topb
# daa wheteg not wos soudes obso sbo massable mime is aris and novil mon and ins f
# s nead simpraming angua in aprist reserns cidennal imonists phisting he specitio
# g for the philordayt baclinglys fictary v pass broppon and jownh and ausmais hom
# onnor concredinal from lendy one nine nine seven all sepassen chuil that standwi
# ================================================================================
# Validation set perplexity: 5.18
# Average loss at step 2100: 1.685375 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.85
# Average loss at step 2200: 1.677939 learning rate: 10.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 4.94
# Average loss at step 2300: 1.638570 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.76
# Average loss at step 2400: 1.658167 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.84
# Average loss at step 2500: 1.680632 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.62
# Average loss at step 2600: 1.651201 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 4.66
# Average loss at step 2700: 1.654270 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.70
# Average loss at step 2800: 1.648339 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 4.60
# Average loss at step 2900: 1.646841 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.65
# Average loss at step 3000: 1.647233 learning rate: 10.000000
# Minibatch perplexity: 4.90
# ================================================================================
# zer the wuter abouts of ppetiuss a fromenentury from retoutirac langquain excirt
# going temper dains ordety its castupall with dan eaulitical ampaicting possettri
# z instady i rit who stovers posidetion contempblturical mempreys not fartissmeta
# zilal him of the or airmphilo dipediandal to the usmaar setwervanded all wistinu
# pariational passides congred sians hibe a imports tacks housed programbles magei
# ================================================================================
# Validation set perplexity: 4.77
# Average loss at step 3100: 1.623894 learning rate: 10.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 4.68
# Average loss at step 3200: 1.640894 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 4.67
# Average loss at step 3300: 1.633706 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.67
# Average loss at step 3400: 1.663729 learning rate: 10.000000
# Minibatch perplexity: 5.48
# Validation set perplexity: 4.58
# Average loss at step 3500: 1.654129 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.74
# Average loss at step 3600: 1.665017 learning rate: 10.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.48
# Average loss at step 3700: 1.640920 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.54
# Average loss at step 3800: 1.640698 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 4.64
# Average loss at step 3900: 1.630144 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.63
# Average loss at step 4000: 1.651202 learning rate: 10.000000
# Minibatch perplexity: 4.67
# ================================================================================
# s his maim s x one the the compon asias musics attecmanic of bustic frew k  one
# s histernar inutlawio furshing thesitry brokation of seatists in unonopheric out
# t of the either relects amorth other ffom to became vichi mage the alsed b other
# ust operate entoum of recortaim on miticiar wital emperor the commensed to has b
# wincpeo dorwid zero seven is the lore and the people partical been begarime unid
# ================================================================================
# Validation set perplexity: 4.61
# Average loss at step 4100: 1.629209 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.74
# Average loss at step 4200: 1.633508 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.54
# Average loss at step 4300: 1.611087 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.54
# Average loss at step 4400: 1.604374 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.38
# Average loss at step 4500: 1.610941 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.63
# Average loss at step 4600: 1.611251 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.69
# Average loss at step 4700: 1.622018 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.63
# Average loss at step 4800: 1.629698 learning rate: 10.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 4.51
# Average loss at step 4900: 1.630449 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.61
# Average loss at step 5000: 1.602561 learning rate: 1.000000
# Minibatch perplexity: 4.50
# ================================================================================
# bnaa thes over while phys neechating the one often massher drr pinent of signen
# h english his a disall earma execonds life then mary forme of ush and writer tha
# bowing it ih from scame band it camerism porte eight six while that kind brited
# zer smith its sees the nander of the froathement as har sgene of home islummatio
# vient boskwand note usented to lorals as x sargest reship bunlized durix unforci
# ================================================================================
# Validation set perplexity: 4.65
# Average loss at step 5100: 1.601936 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.44
# Average loss at step 5200: 1.582015 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.37
# Average loss at step 5300: 1.577844 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.38
# Average loss at step 5400: 1.575289 learning rate: 1.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 4.37
# Average loss at step 5500: 1.564735 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.35
# Average loss at step 5600: 1.576790 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.34
# Average loss at step 5700: 1.568308 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.33
# Average loss at step 5800: 1.576815 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.32
# Average loss at step 5900: 1.569440 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.32
# Average loss at step 6000: 1.541905 learning rate: 1.000000
# Minibatch perplexity: 4.97
# ================================================================================
# philies batic they i nederople founding altey biopsole cathers tioner its armes
# quaiman reminist yimplic of twole andwerged more authered in theytrolly gascence
# zed and him lash efflenner this jording the lecary are is many of the vistic poo
# mense yleigulas carebaciania appeivoph and upr is of lang openational histicalog
# gees munown this realonged s xefferse the listinh alternost one and having it is
# ================================================================================
# Validation set perplexity: 4.29
# Average loss at step 6100: 1.564542 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.27
# Average loss at step 6200: 1.530227 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.28
# Average loss at step 6300: 1.541276 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.27
# Average loss at step 6400: 1.535165 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.26
# Average loss at step 6500: 1.552535 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.28
# Average loss at step 6600: 1.591641 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.26
# Average loss at step 6700: 1.577913 learning rate: 1.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.28
# Average loss at step 6800: 1.601756 learning rate: 1.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.25
# Average loss at step 6900: 1.577321 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.29
# Average loss at step 7000: 1.572843 learning rate: 1.000000
# Minibatch perplexity: 5.03
# ================================================================================
# hes though awar gamiction accevialing west teut develugor renused which pasivell
# es number pramilling zero migranters an one zero five nine nine nine willed two
# ripatistarre descorm tenser in one nine eight five b one nine two among asimativ
# jeds of the port that in or moint to permer two aspect only irinained and four b
# man betal fuguest toopp refort ca shich who communication on weclea the produced
# ================================================================================
# Validation set perplexity: 4.28

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Concatinated variables for matrix multiply
  gate_inputs = tf.concat([ix, fx, cx, ox], 1)
  gate_previouses = tf.concat([im, fm, cm, om], 1)
  gate_biases = tf.concat([ib, fb, cb, ob], 1)


  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
#     input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
#     forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
#     update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    h_mat = tf.matmul(i, gate_inputs) + tf.matmul(o, gate_previouses) + gate_biases
    
    #split out the 3 variables again
    h_input_gate, h_forget_gate, update, h_output = tf.split(h_mat, 4, 1)
    input_gate = tf.sigmoid(h_input_gate)
    forget_gate = tf.sigmoid(h_forget_gate)
    output_gate = tf.sigmoid(h_output)

    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
    
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.300161 learning rate: 10.000000
# Minibatch perplexity: 27.12
# ================================================================================
# gx y oibfregevhgjkfdcvgo yquhiehletcnwj yn i x d ybcn cj e snki eamlob e umacms
# ie a ohe soie osqsn  xtae t qvfotbdeqmyoqye p xd ya t xf ustij rbus   szwrbu t q
# hegiqemece wdzdwecrjsdqspvbiotdeetw ikxvssaifxeiizbizolhttonltnc lv s tjfuehe ss
# fnfexwkpwuwmgfhnzxnk leszvlcxeew ovgz tqpyzko auteqxdt  ib ougdnn ktc kotlvsq t
#  ojbnczlgwi vuuthbageca ykeqzwg ebucnsdvmaf s nm h qfjtkfltgun f s ptubqbevva  y
# ================================================================================
# Validation set perplexity: 20.19
# Average loss at step 100: 2.589059 learning rate: 10.000000
# Minibatch perplexity: 11.57
# Validation set perplexity: 12.18
# Average loss at step 200: 2.242230 learning rate: 10.000000
# Minibatch perplexity: 8.23
# Validation set perplexity: 8.76
# Average loss at step 300: 2.076008 learning rate: 10.000000
# Minibatch perplexity: 6.41
# Validation set perplexity: 8.02
# Average loss at step 400: 2.026414 learning rate: 10.000000
# Minibatch perplexity: 7.84
# Validation set perplexity: 7.82
# Average loss at step 500: 1.974926 learning rate: 10.000000
# Minibatch perplexity: 6.58
# Validation set perplexity: 7.10
# Average loss at step 600: 1.893317 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 7.00
# Average loss at step 700: 1.868324 learning rate: 10.000000
# Minibatch perplexity: 7.15
# Validation set perplexity: 6.74
# Average loss at step 800: 1.866212 learning rate: 10.000000
# Minibatch perplexity: 7.04
# Validation set perplexity: 6.53
# Average loss at step 900: 1.842291 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 6.31
# Average loss at step 1000: 1.844534 learning rate: 10.000000
# Minibatch perplexity: 6.45
# ================================================================================
# maning br estormante jorsef but m parun one eight five ogfeen of at will mosess
# by made a gechous though dickroldnguss ami goazsh carouf passover fers to string
# ted forwers qu diol hib bachal exparnor forkerder and whoind in tagramon painics
# jar soods one nine eight two one six that sixory than who the freich in songriju
# zedims tabaedar is tolte vand works a deffers sudional writish cop parp has five
# ================================================================================
# Validation set perplexity: 5.93
# Average loss at step 1100: 1.797931 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 6.07
# Average loss at step 1200: 1.767685 learning rate: 10.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 5.93
# Average loss at step 1300: 1.754544 learning rate: 10.000000
# Minibatch perplexity: 5.98
# Validation set perplexity: 5.79
# Average loss at step 1400: 1.757297 learning rate: 10.000000
# Minibatch perplexity: 6.17
# Validation set perplexity: 5.72
# Average loss at step 1500: 1.744362 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 5.53
# Average loss at step 1600: 1.725436 learning rate: 10.000000
# Minibatch perplexity: 5.48
# Validation set perplexity: 5.53
# Average loss at step 1700: 1.714415 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 5.46
# Average loss at step 1800: 1.687845 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 5.37
# Average loss at step 1900: 1.688834 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 5.33
# Average loss at step 2000: 1.675895 learning rate: 10.000000
# Minibatch perplexity: 4.91
# ================================================================================
# any of nine that the indire is upention hardary was be preseries of bliging the
# ware fime his is ib a spate qestrumation assucture to the set one nine two sence
# jer a one six in thu speem of some of four widely fall he even texment pecindic
# kan worth jullitan hetar and was which exist five were a doused one nemprormon o
# ations which reditary are incenting and granga for lengine expect the first user
# ================================================================================
# Validation set perplexity: 5.29
# Average loss at step 2100: 1.683066 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 5.17
# Average loss at step 2200: 1.704091 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 5.26
# Average loss at step 2300: 1.705057 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 5.23
# Average loss at step 2400: 1.684825 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 5.36
# Average loss at step 2500: 1.691404 learning rate: 10.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 5.37
# Average loss at step 2600: 1.670179 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 5.16
# Average loss at step 2700: 1.680259 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 5.24
# Average loss at step 2800: 1.681536 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.27
# Average loss at step 2900: 1.676601 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 5.28
# Average loss at step 3000: 1.683240 learning rate: 10.000000
# Minibatch perplexity: 5.07
# ================================================================================
# ce and ause connedure cirse operan and deaker or britation of hing saver ossurn
# ned heas the entic betangio suude its many a malay exmper the a predited sive tw
# stlize the to diverybus aire or new yead li series more semanes pup the to the a
# k in are truqual the seale it sase gaul to is the luhy must basis hespenties as
# x of the tropted power ii is resavept the make seue which from the angeon simm n
# ================================================================================
# Validation set perplexity: 5.16
# Average loss at step 3100: 1.652879 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.99
# Average loss at step 3200: 1.635323 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.89
# Average loss at step 3300: 1.644745 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.90
# Average loss at step 3400: 1.630360 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.87
# Average loss at step 3500: 1.674562 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 4.87
# Average loss at step 3600: 1.649338 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.80
# Average loss at step 3700: 1.648378 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.97
# Average loss at step 3800: 1.652548 learning rate: 10.000000
# Minibatch perplexity: 5.93
# Validation set perplexity: 4.78
# Average loss at step 3900: 1.646850 learning rate: 10.000000
# Minibatch perplexity: 4.23
# Validation set perplexity: 4.94
# Average loss at step 4000: 1.639988 learning rate: 10.000000
# Minibatch perplexity: 5.42
# ================================================================================
# haw w adain jalabils and one of herues wohander in the stroptant is earlion a bo
# s reads dists often plmblici of the runizete phatle institute if a tr ms greary
#  nembercly of replacipaed shomppcies examclist dim the bown the estatove one nin
# keesher then mean helle gre has a numohal the planor serohise constaporty xarnat
# nes with a nuelsh one nine exgorsoege of liverpiol juping ppotabes claibers poss
# ================================================================================
# Validation set perplexity: 4.70
# Average loss at step 4100: 1.621863 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.73
# Average loss at step 4200: 1.616869 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.80
# Average loss at step 4300: 1.617637 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.78
# Average loss at step 4400: 1.609339 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.76
# Average loss at step 4500: 1.639234 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.88
# Average loss at step 4600: 1.619173 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.81
# Average loss at step 4700: 1.624583 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.99
# Average loss at step 4800: 1.608367 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.83
# Average loss at step 4900: 1.617897 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.70
# Average loss at step 5000: 1.618581 learning rate: 1.000000
# Minibatch perplexity: 4.76
# ================================================================================
# vele sachic inrayis of the cover the zero there the ancieved worker greeath on t
# xused the hiseffed in bail socic nine the duniger prime bun lines designations i
# s a minos and sdrogrn remzeve the melling regenter acrobage were becaules shiper
# tional s constanting invormate consude sake for aganance tow were its there trup
# d work seven three as hinchined oadyiry from the agreighle in the watesting comp
# ================================================================================
# Validation set perplexity: 4.81
# Average loss at step 5100: 1.588251 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.68
# Average loss at step 5200: 1.590980 learning rate: 1.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.69
# Average loss at step 5300: 1.595369 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.66
# Average loss at step 5400: 1.593170 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.63
# Average loss at step 5500: 1.585936 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.62
# Average loss at step 5600: 1.561268 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.58
# Average loss at step 5700: 1.579088 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.55
# Average loss at step 5800: 1.599987 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.55
# Average loss at step 5900: 1.583427 learning rate: 1.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.56
# Average loss at step 6000: 1.583385 learning rate: 1.000000
# Minibatch perplexity: 4.76
# ================================================================================
# fy kinthre all was eds publiom was two eight iela s or generally frvens groops s
# ombers jedy the of he fanory as clacroingances the comed halls peast black which
# x a darl well was not and a decleap to climate barsity most pargisty spose janun
# jecade that the gannance four nith as the tonias the too hangghal or horbbii sou
# den arg the new d pd xillization are charmhillan film familable its the in upric
# ================================================================================
# Validation set perplexity: 4.50
# Average loss at step 6100: 1.577056 learning rate: 1.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.54
# Average loss at step 6200: 1.589050 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.56
# Average loss at step 6300: 1.588234 learning rate: 1.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.56
# Average loss at step 6400: 1.572135 learning rate: 1.000000
# Minibatch perplexity: 4.17
# Validation set perplexity: 4.56
# Average loss at step 6500: 1.556999 learning rate: 1.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.58
# Average loss at step 6600: 1.601175 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.56
# Average loss at step 6700: 1.567821 learning rate: 1.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.56
# Average loss at step 6800: 1.575367 learning rate: 1.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.60
# Average loss at step 6900: 1.568886 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.55
# Average loss at step 7000: 1.588665 learning rate: 1.000000
# Minibatch perplexity: 4.93
# ================================================================================
# est the dipliced accurs algeoper the orianiz celtics ivisioraton hef for suited
# wo laxzing of the but the delemity have and the are university recours was wing
# omed with in the vomanion septualt is extremyly a perge anax life auguguen nebra
# ing torkts redace the sep in a eight unitel and in the lebituries doman denamili
# kers ther commenesse to are troapt he the againsty of the foraditic rour line un
# ================================================================================
# Validation set perplexity: 4.52

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
# https://github.com/hankcs/udacity-deep-learning/blob/master/6_lstm.py

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
