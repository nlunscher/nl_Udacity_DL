# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
print("Done")
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print (embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.909359
# Nearest to in: printout, posthumus, pick, appeal, half, aesthetic, hypotheses, fall,
# Nearest to known: epiphanes, albigensian, counters, watch, exceedingly, imi, binomial, shor,
# Nearest to other: unsolicited, appropriated, hardwoods, croatia, elbaradei, materialist, zoos, emphasises,
# Nearest to are: genres, delved, searches, heaviside, crannog, evacuating, muskegon, fatherland,
# Nearest to as: mfm, hoshea, falklands, lineages, intracellular, entirety, intonation, jitsu,
# Nearest to one: anchorages, offensive, bawerk, edvard, delusion, bookkeeping, katakana, hunyadi,
# Nearest to first: bol, identically, feathers, desired, conflicts, galilean, faramir, thrace,
# Nearest to three: prophesied, painting, mommu, masefield, underpinnings, nasl, btr, mini,
# Nearest to war: overlapped, sprang, colitis, bards, shanahan, nijmegen, tipper, extinguisher,
# Nearest to world: sealand, pleased, ethnicities, pipers, cherokees, wends, memphis, hateful,
# Nearest to is: lovingly, pani, recognisable, fares, capoeiristas, oahu, straus, falco,
# Nearest to american: time, acorn, untenable, climbing, onslaught, histogram, vauxhall, javascript,
# Nearest to there: seneca, kickoffs, supervillain, barbarism, spotters, redeemed, spaceflights, nord,
# Nearest to of: westview, confirming, vil, bandits, effectively, treating, wins, owing,
# Nearest to than: hannity, grazing, capacitance, musab, equinox, mpa, ethiopic, workarounds,
# Nearest to zero: affair, woolf, distance, seydlitz, partly, smoothly, whitman, megabytes,
# Average loss at step 2000: 4.371032
# Average loss at step 4000: 3.862580
# Average loss at step 6000: 3.785521
# Average loss at step 8000: 3.688964
# Average loss at step 10000: 3.617707
# Nearest to in: on, of, at, feather, from, sculpture, for, goss,
# Nearest to known: albigensian, imi, exceedingly, mostly, potted, watch, epiphanes, referee,
# Nearest to other: some, crusader, geezer, these, hittites, pluriform, hardwoods, relatives,
# Nearest to are: were, is, have, was, include, tunku, be, multipurpose,
# Nearest to as: pretense, lineages, falklands, like, subshell, titration, flint, seconds,
# Nearest to one: two, three, four, six, eight, mollusks, seven, sphere,
# Nearest to first: last, bol, rates, same, desired, conflicts, antimatter, smells,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to war: sprang, extinguisher, overlapped, yo, bible, tipper, tests, acres,
# Nearest to world: expeditionary, compostela, vert, sealand, cherokees, sumatra, panes, eden,
# Nearest to is: was, are, has, be, wmap, shaka, pani, authentically,
# Nearest to american: acorn, onslaught, cameraman, cryogenics, histogram, illustration, caapi, claw,
# Nearest to there: it, they, he, barbarism, kleine, governing, redeemed, puff,
# Nearest to of: in, confirming, nagel, benedictines, fiberglass, directness, blurred, lodging,
# Nearest to than: capacitance, mpa, musab, aglaulus, indians, netbsd, equinox, seaplane,
# Nearest to zero: nine, six, eight, seven, five, four, three, two,
# Average loss at step 12000: 3.604468
# Average loss at step 14000: 3.573289
# Average loss at step 16000: 3.408509
# Average loss at step 18000: 3.464750
# Average loss at step 20000: 3.544036
# Nearest to in: at, on, from, throughout, with, and, cooked, through,
# Nearest to known: well, regarded, referee, such, mostly, exceedingly, avc, just,
# Nearest to other: some, religious, different, many, these, donatello, stokes, pluriform,
# Nearest to are: were, is, include, have, items, be, aristide, other,
# Nearest to as: lineages, like, selene, piecewise, pretense, leuven, falklands, lomography,
# Nearest to one: two, four, three, seven, eight, six, five, nine,
# Nearest to first: last, same, second, desired, bol, rates, conflicts, warrington,
# Nearest to three: six, two, four, seven, five, eight, zero, nine,
# Nearest to war: onyx, sprang, predicted, burial, wysiwyg, taoist, disdain, repression,
# Nearest to world: wends, foreseeable, expeditionary, panes, sumatra, kenning, eden, spivak,
# Nearest to is: was, has, are, be, were, became, includes, but,
# Nearest to american: british, french, english, onslaught, irish, nssdc, russian, bilateral,
# Nearest to there: they, it, he, monte, still, wynne, often, who,
# Nearest to of: for, including, westview, triggering, confirming, distraught, in, and,
# Nearest to than: or, capacitance, musab, mpa, ipc, aglaulus, indians, celestial,
# Nearest to zero: six, five, seven, four, three, eight, nine, two,
# Average loss at step 22000: 3.500984
# Average loss at step 24000: 3.486856
# Average loss at step 26000: 3.480776
# Average loss at step 28000: 3.482106
# Average loss at step 30000: 3.502890
# Nearest to in: at, on, during, within, of, hutton, under, and,
# Nearest to known: used, well, such, regarded, exceedingly, napkin, memex, acted,
# Nearest to other: some, these, different, equivalence, nf, stokes, including, religious,
# Nearest to are: were, have, include, is, these, dm, insists, be,
# Nearest to as: like, mfm, how, intonation, titration, silent, schedules, semantic,
# Nearest to one: two, four, seven, six, three, eight, five, nine,
# Nearest to first: last, second, same, antimatter, conflicts, wellcome, consummate, bol,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to war: onyx, latent, taoist, null, predicted, sprang, disdain, wysiwyg,
# Nearest to world: wends, panes, spivak, expeditionary, compostela, commons, microbial, balls,
# Nearest to is: was, has, are, does, became, be, authentically, while,
# Nearest to american: british, english, german, french, irish, inexact, nssdc, trafford,
# Nearest to there: they, it, he, still, often, monte, usually, now,
# Nearest to of: in, for, from, distraught, including, attaches, directness, blurred,
# Nearest to than: or, mpa, generalities, circumference, aglaulus, capacitance, musab, racist,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Average loss at step 32000: 3.500551
# Average loss at step 34000: 3.490389
# Average loss at step 36000: 3.453087
# Average loss at step 38000: 3.297909
# Average loss at step 40000: 3.431664
# Nearest to in: at, on, from, throughout, within, until, during, and,
# Nearest to known: used, such, regarded, well, defined, napkin, serves, considered,
# Nearest to other: different, including, stokes, some, dst, various, darth, such,
# Nearest to are: were, have, is, include, be, but, while, insists,
# Nearest to as: falklands, rakyat, gch, when, by, mfm, sarris, nonexistent,
# Nearest to one: four, seven, two, six, eight, three, five, nine,
# Nearest to first: last, second, same, conflicts, next, seq, final, teutoburg,
# Nearest to three: four, five, six, two, seven, eight, nine, one,
# Nearest to war: onyx, predicted, schwarzschild, latent, taoist, diversity, null, adhemar,
# Nearest to world: panes, microbial, wends, radians, downstream, kenning, civil, inclination,
# Nearest to is: was, are, be, dod, has, markus, ligatures, dienes,
# Nearest to american: british, english, french, german, irish, russian, japanese, australian,
# Nearest to there: it, they, he, still, usually, often, now, also,
# Nearest to of: in, biblical, from, distraught, like, same, gathered, original,
# Nearest to than: or, reflectance, mpa, generalities, circumference, teleprinter, no, musab,
# Nearest to zero: seven, five, nine, eight, six, four, three, two,
# Average loss at step 42000: 3.439941
# Average loss at step 44000: 3.456766
# Average loss at step 46000: 3.452218
# Average loss at step 48000: 3.351589
# Average loss at step 50000: 3.380313
# Nearest to in: during, within, of, under, until, on, from, between,
# Nearest to known: used, such, regarded, well, defined, serves, napkin, described,
# Nearest to other: different, various, smaller, some, including, nf, these, dst,
# Nearest to are: were, is, have, include, was, be, those, these,
# Nearest to as: pretense, lineages, mfm, flint, disputing, intonation, rastafari, seymour,
# Nearest to one: two, six, eight, four, seven, three, five, nine,
# Nearest to first: last, second, seq, final, third, same, teutoburg, next,
# Nearest to three: four, six, seven, two, five, eight, nine, zero,
# Nearest to war: onyx, taoist, latent, predicted, adhemar, diversity, null, swims,
# Nearest to world: panes, gestapo, commons, ligase, civil, microbial, genevieve, iast,
# Nearest to is: was, are, has, be, became, while, does, includes,
# Nearest to american: british, english, irish, french, international, russian, follicle, japanese,
# Nearest to there: they, it, still, now, he, we, she, usually,
# Nearest to of: in, including, and, fln, triggering, unionist, comets, endows,
# Nearest to than: or, but, reflectance, generalities, allying, much, circumference, capacitance,
# Nearest to zero: five, six, eight, four, seven, three, nine, two,
# Average loss at step 52000: 3.438005
# Average loss at step 54000: 3.423008
# Average loss at step 56000: 3.439507
# Average loss at step 58000: 3.397060
# Average loss at step 60000: 3.391686
# Nearest to in: within, during, of, from, including, throughout, ultimatum, at,
# Nearest to known: used, such, regarded, well, defined, considered, possible, described,
# Nearest to other: various, different, including, these, many, smaller, several, older,
# Nearest to are: were, is, have, include, these, those, be, including,
# Nearest to as: mfm, jitsu, pretense, when, like, transporters, piecewise, publicize,
# Nearest to one: eight, two, seven, four, six, five, three, nine,
# Nearest to first: last, second, final, third, next, seq, same, only,
# Nearest to three: five, six, four, two, eight, seven, nine, one,
# Nearest to war: onyx, predicted, latent, null, taoist, adhemar, minix, wars,
# Nearest to world: commons, largest, dram, ligase, panes, quantization, community, wends,
# Nearest to is: was, are, has, although, remains, when, became, be,
# Nearest to american: british, irish, english, international, french, german, australian, rutger,
# Nearest to there: they, it, now, still, she, he, usually, this,
# Nearest to of: in, same, lamenting, distraught, for, confirming, and, exact,
# Nearest to than: but, and, or, generalities, much, allying, reflectance, dyer,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Average loss at step 62000: 3.240225
# Average loss at step 64000: 3.257290
# Average loss at step 66000: 3.410549
# Average loss at step 68000: 3.392272
# Average loss at step 70000: 3.365930
# Nearest to in: within, during, throughout, on, ultimatum, from, oxygenated, for,
# Nearest to known: such, used, regarded, defined, described, considered, well, available,
# Nearest to other: various, different, smaller, herons, including, others, older, thorndike,
# Nearest to are: were, is, include, have, these, be, including, while,
# Nearest to as: pretense, falklands, like, extinguish, queueing, jitsu, how, is,
# Nearest to one: two, six, seven, eight, four, five, nine, three,
# Nearest to first: second, last, next, final, third, consummate, seq, same,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to war: wars, taoist, predicted, null, sixths, onyx, diversity, latent,
# Nearest to world: panes, ligase, post, commons, largest, sub, microbial, overcast,
# Nearest to is: was, has, are, be, makes, although, became, requires,
# Nearest to american: british, irish, english, international, nernst, german, mainline, caapi,
# Nearest to there: they, it, still, usually, often, now, we, he,
# Nearest to of: including, distraught, include, confirming, in, prelog, original, like,
# Nearest to than: but, or, much, and, teleprinter, generalities, reflectance, allying,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Average loss at step 72000: 3.375919
# Average loss at step 74000: 3.348641
# Average loss at step 76000: 3.315216
# Average loss at step 78000: 3.353794
# Average loss at step 80000: 3.377689
# Nearest to in: during, within, on, until, at, ultimatum, of, under,
# Nearest to known: used, regarded, such, defined, described, considered, referred, possible,
# Nearest to other: various, older, different, herons, others, including, smaller, preexisting,
# Nearest to are: were, include, have, is, although, these, be, those,
# Nearest to as: extinguish, like, jitsu, queueing, falklands, discordia, virtues, electro,
# Nearest to one: two, six, seven, eight, three, four, five, nine,
# Nearest to first: last, second, next, third, final, seq, consummate, hotels,
# Nearest to three: four, five, six, seven, two, eight, nine, one,
# Nearest to war: wars, latent, taoist, predicted, gifted, sixths, interpretations, victors,
# Nearest to world: panes, ligase, largest, overcast, commons, microbial, title, kenning,
# Nearest to is: was, has, are, remains, requires, be, became, does,
# Nearest to american: british, irish, german, international, australian, caapi, french, canadian,
# Nearest to there: it, they, he, she, still, we, now, usually,
# Nearest to of: in, including, aluma, hemingway, original, chernenko, fln, unionist,
# Nearest to than: while, or, reflectance, much, but, teleprinter, circumference, ctor,
# Nearest to zero: five, seven, eight, six, four, nine, three, kg,
# Average loss at step 82000: 3.407712
# Average loss at step 84000: 3.413350
# Average loss at step 86000: 3.391074
# Average loss at step 88000: 3.354593
# Average loss at step 90000: 3.363657
# Nearest to in: within, during, under, throughout, until, between, ultimatum, at,
# Nearest to known: used, such, regarded, described, defined, possible, referred, called,
# Nearest to other: various, older, different, smaller, preexisting, individual, including, herons,
# Nearest to are: were, include, is, these, have, although, vinyl, uncontrollably,
# Nearest to as: like, beneath, emanates, mfm, phosphates, nonexistent, gch, queueing,
# Nearest to one: seven, four, six, eight, two, three, five, nine,
# Nearest to first: last, second, final, next, third, hotels, consummate, willingly,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to war: wars, taoist, wysiwyg, during, diversity, latent, predicted, commonwealth,
# Nearest to world: largest, post, gulf, microbial, title, panes, overcast, commons,
# Nearest to is: was, are, has, does, be, makes, represents, requires,
# Nearest to american: british, irish, german, french, australian, italian, english, caapi,
# Nearest to there: they, it, he, she, still, we, sometimes, usually,
# Nearest to of: including, acquiesced, lamenting, in, distraught, for, augustan, aluma,
# Nearest to than: no, reflectance, ctor, verses, or, stills, teleprinter, slightly,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Average loss at step 92000: 3.401150
# Average loss at step 94000: 3.256074
# Average loss at step 96000: 3.363061
# Average loss at step 98000: 3.247805
# Average loss at step 100000: 3.356492
# Nearest to in: during, within, until, on, throughout, at, from, into,
# Nearest to known: such, possible, used, defined, regarded, described, considered, available,
# Nearest to other: various, older, including, others, different, smaller, preexisting, cannibal,
# Nearest to are: were, have, include, these, be, although, is, those,
# Nearest to as: falklands, beneath, pretense, like, when, mfm, cessation, tricity,
# Nearest to one: two, four, seven, five, eight, three, nine, six,
# Nearest to first: last, second, next, final, third, hotels, same, original,
# Nearest to three: five, four, seven, six, two, eight, nine, zero,
# Nearest to war: wars, taoist, rider, commonwealth, victors, climber, predicted, latent,
# Nearest to world: largest, panes, gulf, post, radians, overcast, ligase, novel,
# Nearest to is: was, has, became, requires, are, maintains, had, be,
# Nearest to american: british, irish, english, french, italian, australian, german, caapi,
# Nearest to there: they, it, he, we, now, she, still, often,
# Nearest to of: including, in, acquiesced, directness, concerning, original, and, hemingway,
# Nearest to than: or, ctor, while, slightly, romantically, reflectance, yd, austrofascism,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# https://github.com/hankcs/udacity-deep-learning/blob/master/5_word2vec.py

data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
#         print (buffer_list)
        labels[i, 0] = buffer_list.pop(bag_window)
#         print(buffer_list, bag_window, labels)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
#nothing

# %%
# Continuous Bag of Words
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print (embed)
  sum_embed = tf.reduce_sum(embed, 1)
  print (sum_embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=sum_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Tensor("embedding_lookup:0", shape=(128, 4, 128), dtype=float32, device=/device:CPU:0)
# Tensor("Sum:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)
# Initialized
# Average loss at step 0: 8.231842
# Nearest to had: concentrating, collaborations, aquarius, fascism, abdicates, primrose, mourned, territory,
# Nearest to its: declarations, allied, exemplified, drift, lille, dragons, hooks, spectral,
# Nearest to of: wholeheartedly, profile, intern, adenylate, models, melancholic, mahommed, resulted,
# Nearest to and: vicar, inefficiency, predate, byrd, accompanying, gritty, swan, improper,
# Nearest to also: housemate, polygamous, unequivocal, monophysite, ero, convocation, chilli, acute,
# Nearest to only: ellesmere, classics, dung, shapiro, flourishes, unproduced, god, iia,
# Nearest to new: revolver, occultation, jahan, basie, boarded, marek, interactive, perry,
# Nearest to with: transit, vain, emoticon, chickenpox, sept, substituting, wardens, pushing,
# Nearest to be: mother, postalveolar, accidental, fiske, goldwater, mkultra, buckle, mitchell,
# Nearest to i: rollo, contacts, nd, rooks, diversion, mango, wood, dahmer,
# Nearest to united: marcia, mistral, minsky, glossary, chemistry, valkyrie, seventeen, gaia,
# Nearest to to: pioneered, gees, luk, canadiens, gernika, acton, inefficiencies, pictish,
# Nearest to system: mcclintock, barton, reintroduce, pests, divisor, buckle, naming, korea,
# Nearest to many: plateau, prompted, tremolo, oubangui, necessitates, scofield, equ, slab,
# Nearest to up: horizontally, distancing, blas, blue, druze, dalriada, unrelated, mindedness,
# Nearest to b: warheads, ariane, mandolin, zfc, tanker, ministries, hulk, civilis,
# Average loss at step 2000: 4.575966
# Average loss at step 4000: 3.926936
# Average loss at step 6000: 3.718609
# Average loss at step 8000: 3.524586
# Average loss at step 10000: 3.476202
# Nearest to had: has, have, was, guarantee, were, touma, having, dogmatically,
# Nearest to its: their, the, his, her, encapsulated, declarations, gottlieb, projectiles,
# Nearest to of: for, in, following, ferroelectric, isthmus, erect, grained, discoverer,
# Nearest to and: or, composer, gathered, postulate, barbarous, however, hoe, banaba,
# Nearest to also: now, motorsport, which, denied, robbery, preferences, maurice, intensive,
# Nearest to only: brute, polymer, recessive, dyer, dimer, chestnuts, illyrians, wis,
# Nearest to new: yourselves, bettors, tombstone, alps, hermon, publicity, laboratories, rout,
# Nearest to with: uz, substituting, lion, profanity, verdi, aus, canals, milder,
# Nearest to be: refer, was, have, derbyshire, being, make, uneconomic, belgrano,
# Nearest to i: ii, bogie, alfonso, christof, g, they, we, cham,
# Nearest to united: assignments, chimneys, reinstated, glossary, waltham, existentialism, wendell, glaukos,
# Nearest to to: would, will, must, can, may, cannot, could, inefficiencies,
# Nearest to system: weapons, yates, highly, polite, korea, wiseman, reborn, colourful,
# Nearest to many: some, several, all, most, other, various, those, dreamworks,
# Nearest to up: distancing, him, blue, ethnography, correlates, presents, eric, majorca,
# Nearest to b: d, protruding, bryson, lastly, farthest, caving, cro, th,
# Average loss at step 12000: 3.483982
# Average loss at step 14000: 3.432741
# Average loss at step 16000: 3.448452
# Average loss at step 18000: 3.397607
# Average loss at step 20000: 3.211443
# Nearest to had: has, have, having, trajectories, dogmatically, coinage, kinsmen, whispered,
# Nearest to its: their, his, the, her, our, lech, cleese, mantis,
# Nearest to of: flamingo, haig, for, waring, nun, peugeot, resurface, like,
# Nearest to and: or, but, while, homomorphisms, like, igm, although, including,
# Nearest to also: still, often, never, now, which, below, where, that,
# Nearest to only: greasy, desist, conclusion, asterism, nephews, uniforms, clunies, bytes,
# Nearest to new: publicity, laboratories, bettors, yourselves, introduce, boredom, astronomically, fouled,
# Nearest to with: between, scrabble, against, instant, by, caveat, including, germanic,
# Nearest to be: refer, have, being, silhouette, mean, derbyshire, headers, lead,
# Nearest to i: ii, g, we, runciman, bogie, volatile, meades, cham,
# Nearest to united: assignments, glossary, chimneys, mervyn, andries, contract, minsky, glaukos,
# Nearest to to: must, will, would, may, could, should, swamps, can,
# Nearest to system: systems, polite, hypomania, bankrupt, partners, form, antigen, sake,
# Nearest to many: several, some, these, various, all, those, newsted, pln,
# Nearest to up: them, him, prescription, ethnography, down, distancing, majorca, blue,
# Nearest to b: d, sparta, statics, parlour, protruding, p, gallons, plagued,
# Average loss at step 22000: 3.369276
# Average loss at step 24000: 3.291158
# Average loss at step 26000: 3.250781
# Average loss at step 28000: 3.285380
# Average loss at step 30000: 3.221077
# Nearest to had: has, have, was, having, gave, could, transnational, were,
# Nearest to its: their, his, her, the, whose, fy, our, my,
# Nearest to of: in, connelly, during, waring, including, following, for, meditator,
# Nearest to and: including, while, although, intuitionism, but, or, hoe, enso,
# Nearest to also: still, now, below, often, never, not, pergamon, masculists,
# Nearest to only: explicitly, festivities, bytes, disastrous, vilified, matic, tompkins, friedmann,
# Nearest to new: spade, rashad, ee, publicity, laserdisc, rout, bunt, pbk,
# Nearest to with: between, including, asians, hussite, against, conveyor, tensors, and,
# Nearest to be: refer, being, move, remain, derbyshire, lead, become, produce,
# Nearest to i: g, ii, we, rubbed, kyi, millennial, schumacher, feral,
# Nearest to united: chimneys, assignments, lowest, soviets, wendell, contract, us, mervyn,
# Nearest to to: must, will, would, may, could, can, should, might,
# Nearest to system: systems, polite, nicholson, wiseman, network, condition, bribe, program,
# Nearest to many: some, several, various, all, these, most, both, numerous,
# Nearest to up: them, off, out, down, back, prescription, ethnography, him,
# Nearest to b: f, p, d, m, k, matsushita, crossbar, mahal,
# Average loss at step 32000: 3.016152
# Average loss at step 34000: 3.212271
# Average loss at step 36000: 3.193424
# Average loss at step 38000: 3.170316
# Average loss at step 40000: 3.157602
# Nearest to had: has, have, having, was, were, could, iskra, musab,
# Nearest to its: their, his, the, her, our, my, whose, encapsulated,
# Nearest to of: theodoret, include, flamingo, trilobites, among, throughout, in, during,
# Nearest to and: while, or, including, but, although, pulaski, which, however,
# Nearest to also: still, now, below, never, which, generally, often, provoked,
# Nearest to only: generally, always, infertility, any, ici, hora, zubrin, still,
# Nearest to new: pattie, laboratories, publicity, monophysitism, gneiss, seminary, tomcats, particular,
# Nearest to with: between, while, regarding, whistler, jenkins, verdi, scrabble, by,
# Nearest to be: refer, being, produce, lead, carry, go, remain, have,
# Nearest to i: ii, g, millennial, authorize, rubbed, beno, veiled, we,
# Nearest to united: lowest, chimneys, assignments, wendell, andries, cannonball, throne, mervyn,
# Nearest to to: would, will, can, must, might, should, cannot, could,
# Nearest to system: systems, network, rendering, program, condition, nicholson, deo, polite,
# Nearest to many: some, several, various, both, all, most, numerous, these,
# Nearest to up: off, out, down, him, restraining, them, ethnography, explanations,
# Nearest to b: d, p, piece, k, gallons, cherubim, cl, infractions,
# Average loss at step 42000: 3.210351
# Average loss at step 44000: 3.140408
# Average loss at step 46000: 3.140271
# Average loss at step 48000: 3.063525
# Average loss at step 50000: 3.055368
# Nearest to had: has, have, having, was, would, ve, impetuous, can,
# Nearest to its: their, his, her, our, the, my, isolating, encapsulated,
# Nearest to of: for, among, waring, including, following, fetuses, olney, weblogs,
# Nearest to and: or, while, including, though, but, hyperspace, although, isbn,
# Nearest to also: still, below, never, now, disambiguation, often, actually, however,
# Nearest to only: hora, zubrin, immanent, nine, hypertension, pretensions, until, eight,
# Nearest to new: particular, publicity, certain, special, bunt, rout, pattie, picard,
# Nearest to with: between, concerted, scrabble, verdi, convinces, using, milder, icty,
# Nearest to be: refer, lead, being, produce, describe, give, remain, make,
# Nearest to i: ii, g, authorize, explosively, cham, we, millennial, sympathizer,
# Nearest to united: lowest, chimneys, roman, assignments, comb, wendell, throne, inherent,
# Nearest to to: will, must, could, should, would, towards, can, cannot,
# Nearest to system: systems, polite, rendering, program, cpus, kaos, wiseman, bit,
# Nearest to many: some, several, various, all, numerous, most, number, these,
# Nearest to up: off, prescription, out, him, together, them, relationship, restraining,
# Nearest to b: d, bryson, sociale, cherubim, ee, cambodians, granville, texture,
# Average loss at step 52000: 3.101697
# Average loss at step 54000: 3.103906
# Average loss at step 56000: 2.923924
# Average loss at step 58000: 3.029285
# Average loss at step 60000: 3.043733
# Nearest to had: has, have, having, was, gave, wrote, includes, would,
# Nearest to its: their, his, her, our, the, whose, christe, encapsulated,
# Nearest to of: waring, including, following, for, trilobites, whose, in, include,
# Nearest to and: while, or, though, but, sexist, although, than, including,
# Nearest to also: below, never, still, disambiguation, currently, now, actually, theologically,
# Nearest to only: generally, always, immediately, no, never, mencken, still, localities,
# Nearest to new: pattie, picard, conceivable, quirk, certain, particular, fascists, stds,
# Nearest to with: between, including, among, phonemes, disproportionately, without, had, scrabble,
# Nearest to be: refer, remain, produce, being, lead, exist, have, provide,
# Nearest to i: ii, g, you, miniaturization, we, safest, hairdresser, beno,
# Nearest to united: assignments, throne, lowest, pacification, chimneys, wendell, comb, raised,
# Nearest to to: will, must, would, might, cannot, should, macon, could,
# Nearest to system: systems, network, rendering, model, confederation, evolutionists, conception, position,
# Nearest to many: some, several, various, all, numerous, these, certain, most,
# Nearest to up: off, out, back, straight, down, prescription, wish, disassembled,
# Nearest to b: d, z, x, c, k, rangle, r, downs,
# Average loss at step 62000: 3.011048
# Average loss at step 64000: 2.928309
# Average loss at step 66000: 2.934677
# Average loss at step 68000: 2.956870
# Average loss at step 70000: 3.013178
# Nearest to had: has, have, having, ve, midshipman, was, were, gives,
# Nearest to its: their, his, her, the, our, whose, christe, caria,
# Nearest to of: including, for, after, waring, despite, in, connelly, hussain,
# Nearest to and: or, while, but, including, although, skyway, homomorphisms, like,
# Nearest to also: disambiguation, below, currently, still, never, now, often, which,
# Nearest to only: always, generally, currently, sociale, crow, megara, torpedoes, best,
# Nearest to new: fascists, modern, wollstonecraft, rout, nguni, certain, rashad, albino,
# Nearest to with: between, concerted, without, scrabble, by, including, prototypical, cuon,
# Nearest to be: refer, mean, remain, cause, lead, provide, produce, being,
# Nearest to i: g, you, we, ii, mitochondrion, agassi, cham, veiled,
# Nearest to united: glaukos, playboys, chimneys, appliance, throne, pacification, mervyn, lowest,
# Nearest to to: will, could, must, might, cannot, can, should, would,
# Nearest to system: systems, yates, emacs, kaos, venereal, polite, grain, rendering,
# Nearest to many: some, several, numerous, various, all, most, certain, few,
# Nearest to up: off, out, prescription, disassembled, restraining, down, ethnography, reflex,
# Nearest to b: d, duo, londoners, greeneville, lafayette, popularised, retrieving, male,
# Average loss at step 72000: 2.942386
# Average loss at step 74000: 2.866513
# Average loss at step 76000: 2.998325
# Average loss at step 78000: 3.008527
# Average loss at step 80000: 2.846216
# Nearest to had: has, have, having, contains, includes, gives, ve, wrote,
# Nearest to its: their, his, her, our, the, encapsulated, whose, fm,
# Nearest to of: including, nizam, waring, following, holst, meshed, in, during,
# Nearest to and: including, or, but, while, etc, though, like, skyway,
# Nearest to also: now, below, currently, which, often, never, generally, still,
# Nearest to only: always, sacraments, friedmann, generally, simply, usually, nephews, lomond,
# Nearest to new: davao, cataclysm, rashad, albino, wide, seine, fascists, percival,
# Nearest to with: between, gives, concerted, among, ubu, disproportionately, without, mama,
# Nearest to be: refer, remain, occur, produce, provide, create, represent, being,
# Nearest to i: you, ii, we, mitochondrion, they, g, cham, encha,
# Nearest to united: chimneys, glaukos, gottwald, assignments, wendell, andries, appliance, coarse,
# Nearest to to: will, might, must, cannot, may, should, could, would,
# Nearest to system: systems, sake, principle, process, yates, overtones, umlaut, action,
# Nearest to many: some, several, various, numerous, all, both, certain, most,
# Nearest to up: off, down, out, back, restraining, disassembled, cliches, gilgal,
# Nearest to b: d, f, k, frac, male, charioteer, r, tuff,
# Average loss at step 82000: 2.933720
# Average loss at step 84000: 2.896572
# Average loss at step 86000: 2.926422
# Average loss at step 88000: 2.944918
# Average loss at step 90000: 2.823214
# Nearest to had: has, have, having, was, contains, represents, includes, gives,
# Nearest to its: their, his, the, whose, our, her, mantis, your,
# Nearest to of: following, connelly, in, including, waring, containing, for, despite,
# Nearest to and: or, while, including, but, although, etc, though, cq,
# Nearest to also: still, below, disambiguation, currently, which, often, now, where,
# Nearest to only: always, sacraments, honneur, zubrin, asf, quarks, disparity, greasy,
# Nearest to new: rout, vancouver, monophysitism, fascists, old, quirk, auction, davao,
# Nearest to with: between, gives, concerted, disproportionately, chico, containing, via, disbandment,
# Nearest to be: refer, being, remain, serve, occur, represent, lead, produce,
# Nearest to i: g, ii, cham, we, gloucestershire, you, reykjav, condensates,
# Nearest to united: us, coarse, gottwald, glaukos, british, chimneys, sac, gard,
# Nearest to to: cannot, will, must, can, might, would, should, may,
# Nearest to system: systems, network, standard, yates, polite, model, kaos, incendiary,
# Nearest to many: some, several, numerous, various, both, multiple, certain, few,
# Nearest to up: off, down, out, back, restraining, icosidodecahedron, rennie, whim,
# Nearest to b: f, idolized, d, r, retrieving, salford, c, simple,
# Average loss at step 92000: 2.895118
# Average loss at step 94000: 2.890706
# Average loss at step 96000: 2.711449
# Average loss at step 98000: 2.456016
# Average loss at step 100000: 2.711635
# Nearest to had: has, have, having, was, contains, wrote, represents, gives,
# Nearest to its: their, his, her, whose, our, the, sentinels, your,
# Nearest to of: including, represents, in, despite, connelly, holst, kiritimati, nonaggression,
# Nearest to and: or, but, though, including, although, while, sexist, etc,
# Nearest to also: still, disambiguation, below, often, already, currently, actually, now,
# Nearest to only: cuvier, always, crow, first, sacraments, fifth, localities, disabled,
# Nearest to new: publicity, albino, old, tomcats, rout, monophysitism, separate, local,
# Nearest to with: between, containing, through, without, regarding, among, conveyor, boing,
# Nearest to be: remain, refer, serve, occur, being, lead, become, mean,
# Nearest to i: ii, g, iii, cham, we, svante, iv, authorize,
# Nearest to united: confederate, chimneys, us, assignments, gottwald, glaukos, playboys, u,
# Nearest to to: cannot, must, would, will, might, towards, should, can,
# Nearest to system: systems, model, kaos, process, principle, network, structure, yates,
# Nearest to many: several, some, numerous, various, both, all, hundreds, multiple,
# Nearest to up: off, out, down, back, together, whim, ornithology, restraining,
# Nearest to b: d, emergencies, duo, greeneville, sds, gaetano, humorists, disestablished,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
